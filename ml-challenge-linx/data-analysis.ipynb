# %%
import pandas as pd

# %%
tp = pd.read_csv('input/data.csv', sep=',', iterator=True, chunksize=1000)
#print tp
#<pandas.io.parsers.TextFileReader object at 0x00000000150E0048>
df = pd.concat(tp, ignore_index=True)

# %%
df.head()
# Out:
#    source                                       uid gender event_type  \
# 0     NaN  7f5dcd82442966b05f4ebba588c40357752d4a70      F   pageview
# 1     NaN  edb9cbe0bc232ae6ec219fefcf57dfbf0adaec8a      M   pageview
# 2     NaN  edb9cbe0bc232ae6ec219fefcf57dfbf0adaec8a      M   pageview
# 3     NaN  edb9cbe0bc232ae6ec219fefcf57dfbf0adaec8a      M   pageview
# 4     NaN  b8026364c974ef373aaac058558fbb358cdd2e19      M   pageview
#
#   page_type  date            timestamp  productId  \
# 0      cart   NaN  2016-01-01 12:56:13        NaN
# 1      cart   NaN  2016-01-01 13:41:38        NaN
# 2  checkout   NaN  2016-01-01 13:54:50        NaN
# 3  checkout   NaN  2016-01-01 13:55:50        NaN
# 4      cart   NaN  2016-01-01 14:23:44        NaN
#
#    pId_0d5597cab610822b4788e2ada9b83cddb9639f75  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# ...
